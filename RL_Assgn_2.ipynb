# %% [markdown]
# <a href="https://colab.research.google.com/github/SharanSaiVarshith/Reinforcement_Learning/blob/main/RL_Assgn_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Multi-Armed Bandit - Greedy Algorithm
# Arithmetic Mean Method

# Number of machines
n = int(input("Enter number of machines: "))

machines = {}

# Take rewards for each machine
for i in range(n):
    name = input(f"\nEnter name of machine {i + 1}: ")
    rewards = list(map(float, input("Enter rewards separated by spaces: ").split()))
    machines[name] = rewards

print("\n--- Estimated Q Values ---")

q_values = {}

# Calculate arithmetic mean
for name, rewards in machines.items():
    q = sum(rewards) / len(rewards)
    q_values[name] = q

    print(f"Machine {name}")
    print(f"Rewards: {rewards}")
    print(f"Q({name}) = {q:.2f}")

# Greedy selection
selected_machine = max(q_values, key=q_values.get)

print("\nGreedy Selected Machine:", selected_machine)
# Out:
# Enter number of machines: 3
#
# Enter name of machine 1: A
# Enter rewards separated by spaces: 3 4 2 5
#
# Enter name of machine 2: B
# Enter rewards separated by spaces: 6 7 5 8
#
# Enter name of machine 3: C
# Enter rewards separated by spaces: 4 3 5 4
#
# --- Estimated Q Values ---
# Machine A
# Rewards: [3.0, 4.0, 2.0, 5.0]
# Q(A) = 3.50
# Machine B
# Rewards: [6.0, 7.0, 5.0, 8.0]
# Q(B) = 6.50
# Machine C
# Rewards: [4.0, 3.0, 5.0, 4.0]
# Q(C) = 4.00
#
# Greedy Selected Machine: B
