# %% [markdown]
# <a href="https://colab.research.google.com/github/SharanSaiVarshith/Reinforcement_Learning/blob/main/RL_Assgn_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1
            state = next_state

        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Average Reward:", round(average_reward, 2))
        print()

    env.close()

print("CliffWalking Environment")
random_agent("CliffWalking-v1", 5)

print("Taxi Environment")
random_agent("Taxi-v4", 5)
# Out:
# CliffWalking Environment
# Episode: 1
# Total Reward: -56802
# Average Reward: -9.44
#
# Episode: 2
# Total Reward: -24541
# Average Reward: -8.89
#
# Episode: 3
# Total Reward: -12599
# Average Reward: -8.92
#
# Episode: 4
# Total Reward: -28158
# Average Reward: -9.05
#
# Episode: 5
# Total Reward: -121626
# Average Reward: -10.03
#
# Taxi Environment
# Episode: 1
# Total Reward: -830
# Average Reward: -4.15
#
# Episode: 2
# Total Reward: -785
# Average Reward: -3.92
#
# Episode: 3
# Total Reward: -857
# Average Reward: -4.29
#
# Episode: 4
# Total Reward: -758
# Average Reward: -3.79
#
# Episode: 5
# Total Reward: -866
# Average Reward: -4.33
